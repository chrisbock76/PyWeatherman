# %%
# Dependencies
import pandas as pd

import requests
import json
from pprint import pprint
from config import MeteoStat_api_key as MeteoKey

# %%
#Find stations based on city name using meteostat api
city_url = "https://api.meteostat.net/v1/stations/search?q=spokane"
city_station = requests.get(f"{city_url}&key={MeteoKey}").json()
#city_station = requests.get(city_url).json()
pprint(city_station)
# Out:
# {'data': [{'country': 'US',
#            'id': '72785',
#            'name': 'Spokane International Airport'},
#           {'country': 'US', 'id': 'KSFF0', 'name': 'Spokane / Yardley'},
#           {'country': 'US',
#            'id': 'KSKA0',
#            'name': 'Spokane / Fairchild Air Force Base'}],
#  'meta': {'source': 'National Oceanic and Atmospheric Administration, '
#                     'Deutscher Wetterdienst'}}

# %%
#Station IDs
Boston_station = "72509"
Miami_station = "72202"
Columbus_station = "72428"
Nashville_station = "72327"
DesMoines_station = "72546"
Atlanta_station = "72219"
Phoenix_station = "72278"
SaltLakeCity_station = "72572"
Spokane_station = "72785"
#Vancouver_station = "71892"
SF_station = "72494"
SanDiego_station = "72290"
StPaulIsland_station = "70308"

#Parameters for pull
start_a = "1951-01"
start_b = "1981-09"
start_c = "2011-09"
end = "2017-12"

# %%
#Research meteostats api documentation for data pull
#url = https://api.meteostat.net/{VERSION}/{PACKAGE}/{METHOD}?{PARAMETERS}
#url = "https://api.meteostat.net/v1/"   #{PACKAGE}/{METHOD}?{PARAMETERS}
#https://api.meteostat.net/v1/history/daily?station=10637&start=2017-01-01&end=2017-12-31&key=XXXXXXXX

# %%
#Get Boston Weather Data from 1951 - 2017
Boston_weather_url = "https://api.meteostat.net/v1/history/monthly?"
Boston_weather_data_a = requests.get(f"{Boston_weather_url}station={Boston_station}&start={start_a}&end={end}&key={MeteoKey}").json()
Boston_weather_data_b = requests.get(f"{Boston_weather_url}station={Boston_station}&start={start_b}&end={end}&key={MeteoKey}").json()
Boston_weather_data_c = requests.get(f"{Boston_weather_url}station={Boston_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(Boston_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get Miami Weather Data from 1951 - 2017
Miami_weather_url = "https://api.meteostat.net/v1/history/monthly?"
Miami_weather_data_a = requests.get(f"{Miami_weather_url}station={Miami_station}&start={start_a}&end={end}&key={MeteoKey}").json()
Miami_weather_data_b = requests.get(f"{Miami_weather_url}station={Miami_station}&start={start_b}&end={end}&key={MeteoKey}").json()
Miami_weather_data_c = requests.get(f"{Miami_weather_url}station={Miami_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(Miami_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get Columbus (NO CLEVELAND DATA?!?) Weather Data from 1951 - 2017
Columbus_weather_url = "https://api.meteostat.net/v1/history/monthly?"
Columbus_weather_data_a = requests.get(f"{Columbus_weather_url}station={Columbus_station}&start={start_a}&end={end}&key={MeteoKey}").json()
Columbus_weather_data_b = requests.get(f"{Columbus_weather_url}station={Columbus_station}&start={start_b}&end={end}&key={MeteoKey}").json()
Columbus_weather_data_c = requests.get(f"{Columbus_weather_url}station={Columbus_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(Columbus_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get Nashville Weather Data from 1951 - 2017
Nashville_weather_url = "https://api.meteostat.net/v1/history/monthly?"
Nashville_weather_data_a = requests.get(f"{Nashville_weather_url}station={Nashville_station}&start={start_a}&end={end}&key={MeteoKey}").json()
Nashville_weather_data_b = requests.get(f"{Nashville_weather_url}station={Nashville_station}&start={start_b}&end={end}&key={MeteoKey}").json()
Nashville_weather_data_c = requests.get(f"{Nashville_weather_url}station={Nashville_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(Nashville_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get Des Moines Weather Data from 1951 - 2017
DesMoines_weather_url = "https://api.meteostat.net/v1/history/monthly?"
DesMoines_weather_data_a = requests.get(f"{DesMoines_weather_url}station={DesMoines_station}&start={start_a}&end={end}&key={MeteoKey}").json()
DesMoines_weather_data_b = requests.get(f"{DesMoines_weather_url}station={DesMoines_station}&start={start_b}&end={end}&key={MeteoKey}").json()
DesMoines_weather_data_c = requests.get(f"{DesMoines_weather_url}station={DesMoines_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(DesMoines_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get Atlanta Weather Data from 1951 - 2017
Atlanta_weather_url = "https://api.meteostat.net/v1/history/monthly?"
Atlanta_weather_data_a = requests.get(f"{Atlanta_weather_url}station={Atlanta_station}&start={start_a}&end={end}&key={MeteoKey}").json()
Atlanta_weather_data_b = requests.get(f"{Atlanta_weather_url}station={Atlanta_station}&start={start_b}&end={end}&key={MeteoKey}").json()
Atlanta_weather_data_c = requests.get(f"{Atlanta_weather_url}station={Atlanta_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
pprint(Atlanta_weather_data_a)
# Out:
# {'data': [{'month': '1951-02',
#            'precipitation': 100,
#            'pressure': 1023,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-03',
#            'precipitation': 120,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-04',
#            'precipitation': 120,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 15.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-05',
#            'precipitation': 10,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 21.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-06',
#            'precipitation': 120,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-07',
#            'precipitation': 190,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-08',
#            'precipitation': 30,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 27.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-09',
#            'precipitation': 140,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 23.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-10',
#            'precipitation': 70,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.5,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-11',
#            'precipitation': 70,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1951-12',
#            'precipitation': 210,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-01',
#            'precipitation': 90,
#            'pressure': 1023,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 9.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-02',
#            'precipitation': 110,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 9.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-03',
#            'precipitation': 220,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-04',
#            'precipitation': 50,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-05',
#            'precipitation': 100,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-06',
#            'precipitation': 70,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 28.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-07',
#            'precipitation': 30,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 27.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-08',
#            'precipitation': 180,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-09',
#            'precipitation': 30,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-10',
#            'precipitation': 20,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 15.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-11',
#            'precipitation': 50,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1952-12',
#            'precipitation': 150,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-01',
#            'precipitation': 140,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-02',
#            'precipitation': 150,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-03',
#            'precipitation': 90,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-04',
#            'precipitation': 170,
#            'pressure': 1013,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 15.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-05',
#            'precipitation': 90,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 23.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-06',
#            'precipitation': 50,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-07',
#            'precipitation': 110,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-08',
#            'precipitation': 40,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-09',
#            'precipitation': 190,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-10',
#            'precipitation': 2,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 17.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-11',
#            'precipitation': 30,
#            'pressure': 1022,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1953-12',
#            'precipitation': 200,
#            'pressure': 1022,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-01',
#            'precipitation': 90,
#            'pressure': 1023,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 7.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-02',
#            'precipitation': 70,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 10.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-03',
#            'precipitation': 80,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-04',
#            'precipitation': 50,
#            'pressure': 1022,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-05',
#            'precipitation': 80,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-06',
#            'precipitation': 50,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-07',
#            'precipitation': 150,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 27.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-08',
#            'precipitation': 30,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 28.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-09',
#            'precipitation': 6,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-10',
#            'precipitation': 4,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-11',
#            'precipitation': 110,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 9.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1954-12',
#            'precipitation': 80,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-01',
#            'precipitation': 130,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-02',
#            'precipitation': 100,
#            'pressure': 1023,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-03',
#            'precipitation': 80,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 13.5,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-04',
#            'precipitation': 110,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-05',
#            'precipitation': 60,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-06',
#            'precipitation': 90,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-07',
#            'precipitation': 170,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-08',
#            'precipitation': 40,
#            'pressure': 1014,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-09',
#            'precipitation': 20,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-10',
#            'precipitation': 30,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-11',
#            'precipitation': 70,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 10.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1955-12',
#            'precipitation': 30,
#            'pressure': 1023,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-01',
#            'precipitation': 50,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 5.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-02',
#            'precipitation': 170,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 10.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-03',
#            'precipitation': 150,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-04',
#            'precipitation': 130,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-05',
#            'precipitation': 70,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-06',
#            'precipitation': 50,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-07',
#            'precipitation': 180,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-08',
#            'precipitation': 30,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 27,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-09',
#            'precipitation': 160,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-10',
#            'precipitation': 30,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-11',
#            'precipitation': 40,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 10.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1956-12',
#            'precipitation': 80,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-01',
#            'precipitation': 140,
#            'pressure': 1025,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 7.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-02',
#            'precipitation': 50,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-03',
#            'precipitation': 120,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-04',
#            'precipitation': 150,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-05',
#            'precipitation': 90,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 21.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-06',
#            'precipitation': 80,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-07',
#            'precipitation': 80,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-08',
#            'precipitation': 90,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-09',
#            'precipitation': 130,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 23.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-10',
#            'precipitation': 70,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 14.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-11',
#            'precipitation': 170,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1957-12',
#            'precipitation': 80,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-01',
#            'precipitation': 100,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-02',
#            'precipitation': 150,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 3.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-03',
#            'precipitation': 130,
#            'pressure': 1014,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 10,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-04',
#            'precipitation': 110,
#            'pressure': 1014,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-05',
#            'precipitation': 100,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 21.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-06',
#            'precipitation': 100,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-07',
#            'precipitation': 220,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-08',
#            'precipitation': 90,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-09',
#            'precipitation': 80,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 23.5,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-10',
#            'precipitation': 40,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-11',
#            'precipitation': 50,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 13.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1958-12',
#            'precipitation': 70,
#            'pressure': 1022,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-01',
#            'precipitation': 90,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 5.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-02',
#            'precipitation': 90,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-03',
#            'precipitation': 170,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 10.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-04',
#            'precipitation': 70,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 17.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-05',
#            'precipitation': 140,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-06',
#            'precipitation': 40,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-07',
#            'precipitation': 80,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-08',
#            'precipitation': 40,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-09',
#            'precipitation': 90,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-10',
#            'precipitation': 180,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-11',
#            'precipitation': 30,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1959-12',
#            'precipitation': 60,
#            'pressure': None,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 7.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-01',
#            'precipitation': 260,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-02',
#            'precipitation': 130,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-03',
#            'precipitation': 130,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 5.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-04',
#            'precipitation': 120,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 17.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-05',
#            'precipitation': 20,
#            'pressure': 1014,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 20.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-06',
#            'precipitation': 30,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-07',
#            'precipitation': 60,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-08',
#            'precipitation': 140,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-09',
#            'precipitation': 120,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 23.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-10',
#            'precipitation': 70,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-11',
#            'precipitation': 20,
#            'pressure': 1022,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1960-12',
#            'precipitation': 60,
#            'pressure': 1025,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 4.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-01',
#            'precipitation': 40,
#            'pressure': 1022,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 3.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-02',
#            'precipitation': 320,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 9.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-03',
#            'precipitation': 190,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-04',
#            'precipitation': 130,
#            'pressure': 1015,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 13.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-05',
#            'precipitation': 80,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 18.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-06',
#            'precipitation': 190,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-07',
#            'precipitation': 60,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-08',
#            'precipitation': 130,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-09',
#            'precipitation': 40,
#            'pressure': 1019,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-10',
#            'precipitation': 2,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-11',
#            'precipitation': 60,
#            'pressure': 1020,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1961-12',
#            'precipitation': 250,
#            'pressure': 1021,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 6.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-01',
#            'precipitation': 130,
#            'pressure': 1023,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 5,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-02',
#            'precipitation': 130,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 10.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-03',
#            'precipitation': 170,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-04',
#            'precipitation': 150,
#            'pressure': 1014,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 14.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-05',
#            'precipitation': 10,
#            'pressure': 1018,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 23.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-06',
#            'precipitation': 110,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-07',
#            'precipitation': 130,
#            'pressure': 1016,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-08',
#            'precipitation': 30,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-09',
#            'precipitation': 90,
#            'pressure': 1017,
#            'raindays': None,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 21.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1962-10',
#            'precipitation': 40,
#            'pressure': 1018,
# ...
#            'temperature_max': None,
#            'temperature_mean': 17.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1977-05',
#            'precipitation': 52,
#            'pressure': None,
#            'raindays': 5,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 21.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1977-06',
#            'precipitation': 73,
#            'pressure': 1015.4,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1977-07',
#            'precipitation': 108,
#            'pressure': None,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1977-08',
#            'precipitation': 108,
#            'pressure': 1018.4,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1977-09',
#            'precipitation': 124,
#            'pressure': None,
#            'raindays': 12,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 23.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1977-10',
#            'precipitation': 127,
#            'pressure': 1018.1,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 15.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1977-11',
#            'precipitation': 182,
#            'pressure': 1018.2,
#            'raindays': 11,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1977-12',
#            'precipitation': 60,
#            'pressure': 1018.5,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 5.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-01',
#            'precipitation': 178,
#            'pressure': 1020.2,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 0.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-02',
#            'precipitation': 26,
#            'pressure': 1018.3,
#            'raindays': 4,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 4.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-03',
#            'precipitation': 67,
#            'pressure': 1017.4,
#            'raindays': 11,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 10.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-04',
#            'precipitation': 89,
#            'pressure': 1015.6,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-05',
#            'precipitation': 185,
#            'pressure': 1014.6,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 19.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-06',
#            'precipitation': 73,
#            'pressure': 1017.9,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-08',
#            'precipitation': 144,
#            'pressure': None,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 25.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-09',
#            'precipitation': 24,
#            'pressure': 1017.8,
#            'raindays': 5,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-10',
#            'precipitation': 36,
#            'pressure': 1019.7,
#            'raindays': 2,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-11',
#            'precipitation': 75,
#            'pressure': 1020.3,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 14.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1978-12',
#            'precipitation': 95,
#            'pressure': 1020.5,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 7.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-01',
#            'precipitation': 128,
#            'pressure': 1019.2,
#            'raindays': 13,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 2.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-02',
#            'precipitation': 145,
#            'pressure': 1020.8,
#            'raindays': 11,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 5.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-03',
#            'precipitation': 81,
#            'pressure': 1021.4,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 13.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-04',
#            'precipitation': 163,
#            'pressure': 1016.7,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-05',
#            'precipitation': 62,
#            'pressure': 1016.1,
#            'raindays': 12,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 21.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-06',
#            'precipitation': 37,
#            'pressure': 1018.4,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 24.3,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-07',
#            'precipitation': 185,
#            'pressure': 1018.1,
#            'raindays': 11,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-08',
#            'precipitation': 185,
#            'pressure': 1017.9,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.7,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-09',
#            'precipitation': 154,
#            'pressure': 1015.4,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.6,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-10',
#            'precipitation': 55,
#            'pressure': 1016.7,
#            'raindays': 4,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 16.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-11',
#            'precipitation': 132,
#            'pressure': 1020,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 12.4,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1979-12',
#            'precipitation': 18,
#            'pressure': 1021.9,
#            'raindays': 4,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-01',
#            'precipitation': 145,
#            'pressure': 1018.4,
#            'raindays': 15,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 7.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-02',
#            'precipitation': 68,
#            'pressure': 1019.4,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 5.5,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-03',
#            'precipitation': 296,
#            'pressure': 1016.4,
#            'raindays': 15,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-04',
#            'precipitation': 48,
#            'pressure': 1014,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 17,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-05',
#            'precipitation': 213,
#            'pressure': 1014,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 22.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-06',
#            'precipitation': 114,
#            'pressure': 1016.2,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-07',
#            'precipitation': 19,
#            'pressure': 1015.9,
#            'raindays': 4,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 29.5,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-08',
#            'precipitation': 40,
#            'pressure': 1017,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 28.8,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-09',
#            'precipitation': 121,
#            'pressure': 1017.4,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 26,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-10',
#            'precipitation': 41,
#            'pressure': 1017.7,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 17.9,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-11',
#            'precipitation': 54,
#            'pressure': 1019.7,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11.1,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1980-12',
#            'precipitation': 54,
#            'pressure': 1019.7,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': None,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1981-01',
#            'precipitation': 21,
#            'pressure': 1019.7,
#            'raindays': 4,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 4.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1981-02',
#            'precipitation': 168,
#            'pressure': 1021.4,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 8.2,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None},
#           {'month': '1981-03',
#            'precipitation': 100,
#            'pressure': 1017.1,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': None,
#            'temperature_mean': 11,
#            'temperature_mean_max': None,
#            'temperature_mean_min': None,
#            'temperature_min': None}],
#  'meta': {'source': 'National Oceanic and Atmospheric Administration, '
#                     'Deutscher Wetterdienst'}}

# %%
#Put data into a pandas DataFrame

# %%
#Get San Francisco Weather Data from 1951 - 2017
SF_weather_url = "https://api.meteostat.net/v1/history/monthly?"
SF_weather_data_a = requests.get(f"{SF_weather_url}station={SF_station}&start={start_a}&end={end}&key={MeteoKey}").json()
SF_weather_data_b = requests.get(f"{SF_weather_url}station={SF_station}&start={start_b}&end={end}&key={MeteoKey}").json()
SF_weather_data_c = requests.get(f"{SF_weather_url}station={SF_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(SF_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get San Diego Weather Data from 1951 - 2017
SanDiego_weather_url = "https://api.meteostat.net/v1/history/monthly?"
SanDiego_weather_data_a = requests.get(f"{SanDiego_weather_url}station={SanDiego_station}&start={start_a}&end={end}&key={MeteoKey}").json()
SanDiego_weather_data_b = requests.get(f"{SanDiego_weather_url}station={SanDiego_station}&start={start_b}&end={end}&key={MeteoKey}").json()
SanDiego_weather_data_c = requests.get(f"{SanDiego_weather_url}station={SanDiego_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(SanDiego_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get St. Paul Island (Alaska) Weather Data from 1951 - 2017
StPaulIsland_weather_url = "https://api.meteostat.net/v1/history/monthly?"
StPaulIsland_weather_data_a = requests.get(f"{StPaulIsland_weather_url}station={StPaulIsland_station}&start={start_a}&end={end}&key={MeteoKey}").json()
StPaulIsland_weather_data_b = requests.get(f"{StPaulIsland_weather_url}station={StPaulIsland_station}&start={start_b}&end={end}&key={MeteoKey}").json()
StPaulIsland_weather_data_c = requests.get(f"{StPaulIsland_weather_url}station={StPaulIsland_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(StPaulIsland_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get Phoenix Weather Data from 1951 - 2017
Phoenix_weather_url = "https://api.meteostat.net/v1/history/monthly?"
Phoenix_weather_data_a = requests.get(f"{Phoenix_weather_url}station={Phoenix_station}&start={start_a}&end={end}&key={MeteoKey}").json()
Phoenix_weather_data_b = requests.get(f"{Phoenix_weather_url}station={Phoenix_station}&start={start_b}&end={end}&key={MeteoKey}").json()
Phoenix_weather_data_c = requests.get(f"{Phoenix_weather_url}station={Phoenix_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(Phoenix_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get Salt Lake City Weather Data from 1951 - 2017
SaltLakeCity_weather_url = "https://api.meteostat.net/v1/history/monthly?"
SaltLakeCity_weather_data_a = requests.get(f"{SaltLakeCity_weather_url}station={SaltLakeCity_station}&start={start_a}&end={end}&key={MeteoKey}").json()
SaltLakeCity_weather_data_b = requests.get(f"{SaltLakeCity_weather_url}station={SaltLakeCity_station}&start={start_b}&end={end}&key={MeteoKey}").json()
SaltLakeCity_weather_data_c = requests.get(f"{SaltLakeCity_weather_url}station={SaltLakeCity_station}&start={start_c}&end={end}&key={MeteoKey}").json()

#Look at the data
#pprint(SaltLakeCity_weather_data_c)

# %%
#Put data into a pandas DataFrame

# %%
#Get Spokane Weather Data from 1951 - 2017
Spokane_weather_url = "https://api.meteostat.net/v1/history/monthly?"
Spokane_weather_data_a = requests.get(f"{Spokane_weather_url}station={Spokane_station}&start={start_a}&end={end}&key={MeteoKey}").json()
Spokane_weather_data_b = requests.get(f"{Spokane_weather_url}station={Spokane_station}&start={start_b}&end={end}&key={MeteoKey}").json()
Spokane_weather_data_c = requests.get(f"{Spokane_weather_url}station={Spokane_station}&start={start_c}&end={end}&key={MeteoKey}").json()
#Look at the data
pprint(Spokane_weather_data_c)
# Out:
# {'data': [{'month': '2011-09',
#            'precipitation': 4,
#            'pressure': 1016.1,
#            'raindays': 1,
#            'sunshine': None,
#            'temperature_max': 33.9,
#            'temperature_mean': 18.3,
#            'temperature_mean_max': 26.2,
#            'temperature_mean_min': 10.5,
#            'temperature_min': 4.4},
#           {'month': '2011-10',
#            'precipitation': 19,
#            'pressure': 1017.2,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': 23.9,
#            'temperature_mean': 8.9,
#            'temperature_mean_max': 13.7,
#            'temperature_mean_min': 4.1,
#            'temperature_min': -4.9},
#           {'month': '2011-11',
#            'precipitation': 44,
#            'pressure': 1015.9,
#            'raindays': 11,
#            'sunshine': None,
#            'temperature_max': 13.3,
#            'temperature_mean': 1.7,
#            'temperature_mean_max': 6,
#            'temperature_mean_min': -2.5,
#            'temperature_min': -7.7},
#           {'month': '2011-12',
#            'precipitation': 26,
#            'pressure': 1025.8,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': 9.4,
#            'temperature_mean': -1.8,
#            'temperature_mean_max': 1.2,
#            'temperature_mean_min': -4.8,
#            'temperature_min': -9.3},
#           {'month': '2012-01',
#            'precipitation': 46,
#            'pressure': 1020,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': 11.7,
#            'temperature_mean': -1.1,
#            'temperature_mean_max': 2.5,
#            'temperature_mean_min': -4.7,
#            'temperature_min': -12.7},
#           {'month': '2012-02',
#            'precipitation': 43,
#            'pressure': 1019.4,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': 8.9,
#            'temperature_mean': 0.4,
#            'temperature_mean_max': 3.8,
#            'temperature_mean_min': -2.9,
#            'temperature_min': -14.3},
#           {'month': '2012-03',
#            'precipitation': 116,
#            'pressure': 1010.7,
#            'raindays': 16,
#            'sunshine': None,
#            'temperature_max': 17.2,
#            'temperature_mean': 3.7,
#            'temperature_mean_max': 8,
#            'temperature_mean_min': -0.6,
#            'temperature_min': -6},
#           {'month': '2012-04',
#            'precipitation': 36,
#            'pressure': 1014.1,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': 27.2,
#            'temperature_mean': 9.1,
#            'temperature_mean_max': 14.6,
#            'temperature_mean_min': 3.5,
#            'temperature_min': -3.2},
#           {'month': '2012-05',
#            'precipitation': 18,
#            'pressure': 1015.7,
#            'raindays': 3,
#            'sunshine': None,
#            'temperature_max': 30,
#            'temperature_mean': 12.1,
#            'temperature_mean_max': 18.4,
#            'temperature_mean_min': 5.9,
#            'temperature_min': -1},
#           {'month': '2012-06',
#            'precipitation': 73,
#            'pressure': 1012.6,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': 29.4,
#            'temperature_mean': 15.3,
#            'temperature_mean_max': 21.1,
#            'temperature_mean_min': 9.6,
#            'temperature_min': 3.3},
#           {'month': '2012-07',
#            'precipitation': 21,
#            'pressure': 1013.3,
#            'raindays': 2,
#            'sunshine': None,
#            'temperature_max': 36.7,
#            'temperature_mean': 22.3,
#            'temperature_mean_max': 29.6,
#            'temperature_mean_min': 15,
#            'temperature_min': 6.1},
#           {'month': '2012-08',
#            'precipitation': 3,
#            'pressure': 1013.7,
#            'raindays': 1,
#            'sunshine': None,
#            'temperature_max': 36.1,
#            'temperature_mean': 22,
#            'temperature_mean_max': 30,
#            'temperature_mean_min': 14,
#            'temperature_min': 8.3},
#           {'month': '2012-09',
#            'precipitation': 0,
#            'pressure': 1017.7,
#            'raindays': 0,
#            'sunshine': None,
#            'temperature_max': 30,
#            'temperature_mean': 17.4,
#            'temperature_mean_max': 25.4,
#            'temperature_mean_min': 9.5,
#            'temperature_min': 1.7},
#           {'month': '2012-10',
#            'precipitation': 39,
#            'pressure': 1016.3,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': 24.4,
#            'temperature_mean': 9.2,
#            'temperature_mean_max': 14.4,
#            'temperature_mean_min': 3.9,
#            'temperature_min': -1},
#           {'month': '2012-11',
#            'precipitation': 82,
#            'pressure': 1017.5,
#            'raindays': 13,
#            'sunshine': None,
#            'temperature_max': 13.9,
#            'temperature_mean': 3.8,
#            'temperature_mean_max': 6.9,
#            'temperature_mean_min': 0.8,
#            'temperature_min': -6.6},
#           {'month': '2012-12',
#            'precipitation': 66,
#            'pressure': 1013.2,
#            'raindays': 15,
#            'sunshine': None,
#            'temperature_max': 9.4,
#            'temperature_mean': -0.4,
#            'temperature_mean_max': 2.1,
#            'temperature_mean_min': -2.9,
#            'temperature_min': -12.7},
#           {'month': '2013-01',
#            'precipitation': 41,
#            'pressure': 1024.5,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': 6.1,
#            'temperature_mean': -4,
#            'temperature_mean_max': -0.6,
#            'temperature_mean_min': -7.4,
#            'temperature_min': -15.5},
#           {'month': '2013-02',
#            'precipitation': 19,
#            'pressure': 1020.5,
#            'raindays': 5,
#            'sunshine': None,
#            'temperature_max': 10,
#            'temperature_mean': 1,
#            'temperature_mean_max': 4.4,
#            'temperature_mean_min': -2.3,
#            'temperature_min': -6},
#           {'month': '2013-03',
#            'precipitation': 21,
#            'pressure': 1018.8,
#            'raindays': 3,
#            'sunshine': None,
#            'temperature_max': 20,
#            'temperature_mean': 5.1,
#            'temperature_mean_max': 10.2,
#            'temperature_mean_min': 0.1,
#            'temperature_min': -5.5},
#           {'month': '2013-04',
#            'precipitation': 24,
#            'pressure': 1016.7,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': 22.8,
#            'temperature_mean': 7.8,
#            'temperature_mean_max': 13.5,
#            'temperature_mean_min': 2.1,
#            'temperature_min': -6},
#           {'month': '2013-05',
#            'precipitation': 20,
#            'pressure': 1016.4,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': 30,
#            'temperature_mean': 13.8,
#            'temperature_mean_max': 20.3,
#            'temperature_mean_min': 7.3,
#            'temperature_min': -1},
#           {'month': '2013-06',
#            'precipitation': 47,
#            'pressure': 1014.3,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': 32.8,
#            'temperature_mean': 16.5,
#            'temperature_mean_max': 22.6,
#            'temperature_mean_min': 10.4,
#            'temperature_min': 6.7},
#           {'month': '2013-07',
#            'precipitation': 0,
#            'pressure': 1012.8,
#            'raindays': 0,
#            'sunshine': None,
#            'temperature_max': 37.2,
#            'temperature_mean': 23.3,
#            'temperature_mean_max': 31.2,
#            'temperature_mean_min': 15.4,
#            'temperature_min': 10.6},
#           {'month': '2013-08',
#            'precipitation': 17,
#            'pressure': 1013.3,
#            'raindays': 3,
#            'sunshine': None,
#            'temperature_max': 33.3,
#            'temperature_mean': 22.3,
#            'temperature_mean_max': 29.5,
#            'temperature_mean_min': 15.2,
#            'temperature_min': 11.1},
#           {'month': '2013-09',
#            'precipitation': 40,
#            'pressure': 1011.3,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': 33.3,
#            'temperature_mean': 17.2,
#            'temperature_mean_max': 23,
#            'temperature_mean_min': 11.4,
#            'temperature_min': 5.6},
#           {'month': '2013-10',
#            'precipitation': 2,
#            'pressure': 1020.5,
#            'raindays': 1,
#            'sunshine': None,
#            'temperature_max': 19.4,
#            'temperature_mean': 7.6,
#            'temperature_mean_max': 13.6,
#            'temperature_mean_min': 1.7,
#            'temperature_min': -3.8},
#           {'month': '2013-11',
#            'precipitation': 40,
#            'pressure': 1020.9,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': 11.1,
#            'temperature_mean': 1.6,
#            'temperature_mean_max': 5.1,
#            'temperature_mean_min': -1.9,
#            'temperature_min': -9.3},
#           {'month': '2013-12',
#            'precipitation': 17,
#            'pressure': 1024.1,
#            'raindays': 3,
#            'sunshine': None,
#            'temperature_max': 6.7,
#            'temperature_mean': -3.5,
#            'temperature_mean_max': -0.4,
#            'temperature_mean_min': -6.5,
#            'temperature_min': -18.8},
#           {'month': '2014-01',
#            'precipitation': 26,
#            'pressure': 1024.3,
#            'raindays': 5,
#            'sunshine': None,
#            'temperature_max': 8.3,
#            'temperature_mean': -1.3,
#            'temperature_mean_max': 0.9,
#            'temperature_mean_min': -3.4,
#            'temperature_min': -10.5},
#           {'month': '2014-02',
#            'precipitation': 46,
#            'pressure': 1016.8,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': 7.8,
#            'temperature_mean': -3.3,
#            'temperature_mean_max': 0.1,
#            'temperature_mean_min': -6.6,
#            'temperature_min': -20.5},
#           {'month': '2014-03',
#            'precipitation': 73,
#            'pressure': 1015.6,
#            'raindays': 11,
#            'sunshine': None,
#            'temperature_max': 13.3,
#            'temperature_mean': 4.3,
#            'temperature_mean_max': 9.2,
#            'temperature_mean_min': -0.7,
#            'temperature_min': -11.6},
#           {'month': '2014-04',
#            'precipitation': 29,
#            'pressure': 1015.3,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': 22.2,
#            'temperature_mean': 8.3,
#            'temperature_mean_max': 14.2,
#            'temperature_mean_min': 2.3,
#            'temperature_min': -0.5},
#           {'month': '2014-05',
#            'precipitation': 14,
#            'pressure': 1015.3,
#            'raindays': 3,
#            'sunshine': None,
#            'temperature_max': 26.7,
#            'temperature_mean': 14.3,
#            'temperature_mean_max': 20.7,
#            'temperature_mean_min': 7.9,
#            'temperature_min': 2.8},
#           {'month': '2014-06',
#            'precipitation': 47,
#            'pressure': 1012.6,
#            'raindays': 5,
#            'sunshine': None,
#            'temperature_max': 29.4,
#            'temperature_mean': 16.5,
#            'temperature_mean_max': 22.7,
#            'temperature_mean_min': 10.3,
#            'temperature_min': 6.7},
#           {'month': '2014-07',
#            'precipitation': 5,
#            'pressure': 1013.9,
#            'raindays': 2,
#            'sunshine': None,
#            'temperature_max': 37.8,
#            'temperature_mean': 24.3,
#            'temperature_mean_max': 31.9,
#            'temperature_mean_min': 16.7,
#            'temperature_min': 8.9},
#           {'month': '2014-08',
#            'precipitation': 15,
#            'pressure': 1013.5,
#            'raindays': 3,
#            'sunshine': None,
#            'temperature_max': 36.7,
#            'temperature_mean': 22.3,
#            'temperature_mean_max': 29.4,
#            'temperature_mean_min': 15.3,
#            'temperature_min': 11.1},
#           {'month': '2014-09',
#            'precipitation': 7,
#            'pressure': 1014.1,
#            'raindays': 2,
#            'sunshine': None,
#            'temperature_max': 31.1,
#            'temperature_mean': 17.3,
#            'temperature_mean_max': 24.3,
#            'temperature_mean_min': 10.2,
#            'temperature_min': 3.9},
#           {'month': '2014-10',
#            'precipitation': 36,
#            'pressure': 1014.9,
#            'raindays': 5,
#            'sunshine': None,
#            'temperature_max': 26.7,
#            'temperature_mean': 11.8,
#            'temperature_mean_max': 17.2,
#            'temperature_mean_min': 6.5,
#            'temperature_min': 1.7},
#           {'month': '2014-11',
#            'precipitation': 34,
#            'pressure': 1020.1,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': 15,
#            'temperature_mean': 1.5,
#            'temperature_mean_max': 5.4,
#            'temperature_mean_min': -2.4,
#            'temperature_min': -12.1},
#           {'month': '2014-12',
#            'precipitation': 50,
#            'pressure': 1019.1,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': 13.9,
#            'temperature_mean': 0.5,
#            'temperature_mean_max': 3.4,
#            'temperature_mean_min': -2.4,
#            'temperature_min': -13.2},
#           {'month': '2015-01',
#            'precipitation': 49,
#            'pressure': 1026.2,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': 12.8,
#            'temperature_mean': -0.5,
#            'temperature_mean_max': 1.8,
#            'temperature_mean_min': -2.8,
#            'temperature_min': -13.2},
#           {'month': '2015-02',
#            'precipitation': 27,
#            'pressure': 1020.7,
#            'raindays': 6,
#            'sunshine': None,
#            'temperature_max': 14.4,
#            'temperature_mean': 4,
#            'temperature_mean_max': 8.4,
#            'temperature_mean_min': -0.3,
#            'temperature_min': -7.1},
#           {'month': '2015-03',
#            'precipitation': 62,
#            'pressure': 1019.5,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': 21.1,
#            'temperature_mean': 7.5,
#            'temperature_mean_max': 13.1,
#            'temperature_mean_min': 2,
#            'temperature_min': -7.7},
#           {'month': '2015-04',
#            'precipitation': 14,
#            'pressure': 1016.3,
#            'raindays': 3,
#            'sunshine': None,
#            'temperature_max': 25.6,
#            'temperature_mean': 8.6,
#            'temperature_mean_max': 14.9,
#            'temperature_mean_min': 2.4,
#            'temperature_min': -2.7},
#           {'month': '2015-05',
#            'precipitation': 22,
#            'pressure': 1012.7,
#            'raindays': 5,
#            'sunshine': None,
#            'temperature_max': 28.3,
#            'temperature_mean': 16,
#            'temperature_mean_max': 22.5,
#            'temperature_mean_min': 9.4,
#            'temperature_min': 2.8},
#           {'month': '2015-06',
#            'precipitation': 2,
#            'pressure': 1012.7,
#            'raindays': 1,
#            'sunshine': None,
#            'temperature_max': 40.6,
#            'temperature_mean': 21.9,
#            'temperature_mean_max': 29.4,
#            'temperature_mean_min': 14.5,
#            'temperature_min': 6.1},
#           {'month': '2015-07',
#            'precipitation': 5,
#            'pressure': 1012.2,
#            'raindays': 1,
#            'sunshine': None,
#            'temperature_max': 37.8,
#            'temperature_mean': 23.4,
#            'temperature_mean_max': 30.6,
#            'temperature_mean_min': 16.3,
#            'temperature_min': 9.4},
#           {'month': '2015-08',
#            'precipitation': 5,
#            'pressure': 1012.3,
#            'raindays': 2,
#            'sunshine': None,
#            'temperature_max': 37.8,
#            'temperature_mean': 22.5,
#            'temperature_mean_max': 29.8,
#            'temperature_mean_min': 15.1,
#            'temperature_min': 9.4},
#           {'month': '2015-09',
#            'precipitation': 13,
#            'pressure': 1014.3,
#            'raindays': 2,
#            'sunshine': None,
#            'temperature_max': 31.7,
#            'temperature_mean': 14.9,
#            'temperature_mean_max': 21.5,
#            'temperature_mean_min': 8.4,
#            'temperature_min': 3.3},
#           {'month': '2015-10',
#            'precipitation': 29,
#            'pressure': 1016.5,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': 23.9,
#            'temperature_mean': 12.4,
#            'temperature_mean_max': 18,
#            'temperature_mean_min': 6.8,
#            'temperature_min': 2.2},
#           {'month': '2015-11',
#            'precipitation': 20,
#            'pressure': 1019,
#            'raindays': 5,
#            'sunshine': None,
#            'temperature_max': 14.4,
#            'temperature_mean': 1.6,
#            'temperature_mean_max': 5.6,
#            'temperature_mean_min': -2.3,
#            'temperature_min': -11.6},
#           {'month': '2015-12',
#            'precipitation': 113,
#            'pressure': 1014.4,
#            'raindays': 18,
#            'sunshine': None,
#            'temperature_max': 13.3,
#            'temperature_mean': -0.7,
#            'temperature_mean_max': 2,
#            'temperature_mean_min': -3.3,
#            'temperature_min': -16.6},
#           {'month': '2016-01',
#            'precipitation': 70,
#            'pressure': 1018.3,
#            'raindays': 11,
#            'sunshine': None,
#            'temperature_max': 8.3,
#            'temperature_mean': -0.5,
#            'temperature_mean_max': 1.9,
#            'temperature_mean_min': -3,
#            'temperature_min': -17.1},
#           {'month': '2016-02',
#            'precipitation': 18,
#            'pressure': 1021.8,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': 12.8,
#            'temperature_mean': 3.8,
#            'temperature_mean_max': 7.6,
#            'temperature_mean_min': 0,
#            'temperature_min': -6.6},
#           {'month': '2016-03',
#            'precipitation': 84,
#            'pressure': 1013.9,
#            'raindays': 13,
#            'sunshine': None,
#            'temperature_max': 18.3,
#            'temperature_mean': 5.9,
#            'temperature_mean_max': 10.6,
#            'temperature_mean_min': 1.2,
#            'temperature_min': -2.1},
#           {'month': '2016-04',
#            'precipitation': 8,
#            'pressure': 1015.8,
#            'raindays': 4,
#            'sunshine': None,
#            'temperature_max': 29.4,
#            'temperature_mean': 12.6,
#            'temperature_mean_max': 19,
#            'temperature_mean_min': 6.3,
#            'temperature_min': 0.6},
#           {'month': '2016-05',
#            'precipitation': 20,
#            'pressure': 1014,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': 27.8,
#            'temperature_mean': 14.8,
#            'temperature_mean_max': 20.9,
#            'temperature_mean_min': 8.7,
#            'temperature_min': 3.3},
#           {'month': '2016-06',
#            'precipitation': 13,
#            'pressure': 1015.5,
#            'raindays': 3,
#            'sunshine': None,
#            'temperature_max': 35.6,
#            'temperature_mean': 18.2,
#            'temperature_mean_max': 24.9,
#            'temperature_mean_min': 11.6,
#            'temperature_min': 4.4},
#           {'month': '2016-07',
#            'precipitation': 7,
#            'pressure': 1014,
#            'raindays': 2,
#            'sunshine': None,
#            'temperature_max': 36.1,
#            'temperature_mean': 20.5,
#            'temperature_mean_max': 27.2,
#            'temperature_mean_min': 13.8,
#            'temperature_min': 8.3},
#           {'month': '2016-08',
#            'precipitation': 4,
#            'pressure': 1013.9,
#            'raindays': 1,
#            'sunshine': None,
#            'temperature_max': 33.9,
#            'temperature_mean': 21.8,
#            'temperature_mean_max': 29.2,
#            'temperature_mean_min': 14.3,
#            'temperature_min': 10},
#           {'month': '2016-09',
#            'precipitation': 5,
#            'pressure': 1016.5,
#            'raindays': 2,
#            'sunshine': None,
#            'temperature_max': 28.3,
#            'temperature_mean': 15.4,
#            'temperature_mean_max': 22.1,
#            'temperature_mean_min': 8.7,
#            'temperature_min': 4.4},
#           {'month': '2016-10',
#            'precipitation': 158,
#            'pressure': 1013.2,
#            'raindays': 21,
#            'sunshine': None,
#            'temperature_max': 19.4,
#            'temperature_mean': 9.1,
#            'temperature_mean_max': 12.7,
#            'temperature_mean_min': 5.5,
#            'temperature_min': -1},
#           {'month': '2016-11',
#            'precipitation': 40,
#            'pressure': 1016.8,
#            'raindays': 11,
#            'sunshine': None,
#            'temperature_max': 17.8,
#            'temperature_mean': 6.4,
#            'temperature_mean_max': 9.8,
#            'temperature_mean_min': 2.9,
#            'temperature_min': -1.6},
#           {'month': '2016-12',
#            'precipitation': 38,
#            'pressure': 1021,
#            'raindays': 10,
#            'sunshine': None,
#            'temperature_max': 5,
#            'temperature_mean': -4.9,
#            'temperature_mean_max': -1.5,
#            'temperature_mean_min': -8.3,
#            'temperature_min': -21.6},
#           {'month': '2017-01',
#            'precipitation': 47,
#            'pressure': 1020.3,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': 6.1,
#            'temperature_mean': -6.5,
#            'temperature_mean_max': -2.7,
#            'temperature_mean_min': -10.2,
#            'temperature_min': -19.9},
#           {'month': '2017-02',
#            'precipitation': 112,
#            'pressure': 1013.2,
#            'raindays': 14,
#            'sunshine': None,
#            'temperature_max': 8.3,
#            'temperature_mean': -1.5,
#            'temperature_mean_max': 2.3,
#            'temperature_mean_min': -5.2,
#            'temperature_min': -13.8},
#           {'month': '2017-03',
#            'precipitation': 104,
#            'pressure': 1016.1,
#            'raindays': 16,
#            'sunshine': None,
#            'temperature_max': 15.6,
#            'temperature_mean': 4.9,
#            'temperature_mean_max': 8.6,
#            'temperature_mean_min': 1.2,
#            'temperature_min': -3.8},
#           {'month': '2017-04',
#            'precipitation': 41,
#            'pressure': 1014.7,
#            'raindays': 9,
#            'sunshine': None,
#            'temperature_max': 17.8,
#            'temperature_mean': 7.9,
#            'temperature_mean_max': 12.8,
#            'temperature_mean_min': 3.1,
#            'temperature_min': -1.6},
#           {'month': '2017-05',
#            'precipitation': 33,
#            'pressure': 1014.9,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': 32.2,
#            'temperature_mean': 13.9,
#            'temperature_mean_max': 20,
#            'temperature_mean_min': 7.8,
#            'temperature_min': 1.7},
#           {'month': '2017-06',
#            'precipitation': 18,
#            'pressure': 1013.7,
#            'raindays': 4,
#            'sunshine': None,
#            'temperature_max': 34.4,
#            'temperature_mean': 18.6,
#            'temperature_mean_max': 25.5,
#            'temperature_mean_min': 11.6,
#            'temperature_min': 6.7},
#           {'month': '2017-07',
#            'precipitation': 0,
#            'pressure': 1014.5,
#            'raindays': 0,
#            'sunshine': None,
#            'temperature_max': 37.2,
#            'temperature_mean': 23.6,
#            'temperature_mean_max': 31.4,
#            'temperature_mean_min': 15.9,
#            'temperature_min': 11.1},
#           {'month': '2017-08',
#            'precipitation': 0,
#            'pressure': 1013.6,
#            'raindays': 0,
#            'sunshine': None,
#            'temperature_max': 36.7,
#            'temperature_mean': 23.2,
#            'temperature_mean_max': 31,
#            'temperature_mean_min': 15.4,
#            'temperature_min': 8.9},
#           {'month': '2017-09',
#            'precipitation': 31,
#            'pressure': 1014.8,
#            'raindays': 4,
#            'sunshine': None,
#            'temperature_max': 34.4,
#            'temperature_mean': 16.8,
#            'temperature_mean_max': 22.9,
#            'temperature_mean_min': 10.6,
#            'temperature_min': 2.8},
#           {'month': '2017-10',
#            'precipitation': 36,
#            'pressure': 1019.5,
#            'raindays': 7,
#            'sunshine': None,
#            'temperature_max': 18.9,
#            'temperature_mean': 8.1,
#            'temperature_mean_max': 13.4,
#            'temperature_mean_min': 2.8,
#            'temperature_min': -1.6},
#           {'month': '2017-11',
#            'precipitation': 73,
#            'pressure': 1015.4,
#            'raindays': 16,
#            'sunshine': None,
#            'temperature_max': 13.9,
#            'temperature_mean': 3.2,
#            'temperature_mean_max': 6.4,
#            'temperature_mean_min': 0,
#            'temperature_min': -8.8},
#           {'month': '2017-12',
#            'precipitation': 73,
#            'pressure': 1027.8,
#            'raindays': 8,
#            'sunshine': None,
#            'temperature_max': 5.6,
#            'temperature_mean': -2.9,
#            'temperature_mean_max': -0.4,
#            'temperature_mean_min': -5.3,
#            'temperature_min': -13.8}],
#  'meta': {'source': 'National Oceanic and Atmospheric Administration, '
#                     'Deutscher Wetterdienst'}}

# %%
#Put data into a pandas DataFrame

# %%
#####################################
# ALL CODE BELOW HERE FOR LATER!!!! #
#####################################

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig

# %% [markdown]
# ![08-Airport_Heatmap.png](../Images/08-Airport_Heatmap.png)

# %%
# BONUS
# Plost as a Hybrid map
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig

# %% [markdown]
# ![08-Hybrid_Map.png](../Images/08-Hybrid_Map.png)

# %%
# BONUS
# Plot as a Terrain map
fig = gmaps.figure(map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig

# %% [markdown]
# ![08-Terrain_Map.png](../Images/08-Terrain_Map.png)
